# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from scripts import ensemble_methods as ems
import warnings

# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv('data/labelencoded_data.csv',index_col=0)
df.drop(['id', 'std', 'sta', 'fltid','arr_iata','dep_iata','ac'], axis=1,inplace=True)
X = df.drop(['target'],axis=1)
y = df['target'] 
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# Filter out rows with target value equal to 0 in the training set
X_train_filtered = X_train[y_train != 0]
y_train_filtered = y_train[y_train != 0]

# %%
# XG Boost
# %load_ext autoreload
# %autoreload 2
warnings.filterwarnings("ignore", message="Dataset is empty, or contains only positive or negative samples.")

results = ems.use_xgboost_regression(X_train,X_test,y_train,y_test)
display(results)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#   0%|          | 0/100 [00:00<?, ?trial/s, best loss=?]
# /home/linuxuser/spiced-academy/data-science/flight_delays_ML/.venv/lib/python3.11/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-rmse:121.17058	validation_1-rmse:123.45480
# [1]	validation_0-rmse:118.09997	validation_1-rmse:120.39806
# [2]	validation_0-rmse:116.29605	validation_1-rmse:118.69147
# [3]	validation_0-rmse:115.35257	validation_1-rmse:117.75230
# [4]	validation_0-rmse:114.05472	validation_1-rmse:116.69531
# [5]	validation_0-rmse:113.88105	validation_1-rmse:116.51464
# [6]	validation_0-rmse:113.61269	validation_1-rmse:116.30329
# [7]	validation_0-rmse:113.48048	validation_1-rmse:116.16661
# ...

# %%
display()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# AdaBoost
# %load_ext autoreload
# %autoreload 2
results = ems.use_AdaBoost(X_train,X_test,y_train,y_test)
display("train_data: ",results)
# display("R2 for train data: ",results[0]," R2 for test data: ",results[1])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /home/linuxuser/spiced-academy/data-science/flight_delays_ML/.venv/lib/python3.11/site-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(
# /home/linuxuser/spiced-academy/data-science/flight_delays_ML/.venv/lib/python3.11/site-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(
# /home/linuxuser/spiced-academy/data-science/flight_delays_ML/.venv/lib/python3.11/site-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ...
